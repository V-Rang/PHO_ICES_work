# %%
import h5py
# !pip install wget
# !wget https://darus.uni-stuttgart.de/api/access/datafile/133299 -O dataset_01
dirname = "/content/dataset_01"
data = [h5py.File(dirname, "r")]
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# --2025-08-19 02:51:57--  https://darus.uni-stuttgart.de/api/access/datafile/133299
# Resolving darus.uni-stuttgart.de (darus.uni-stuttgart.de)... 129.69.7.87, 2001:7c0:2041:17f::87
# Connecting to darus.uni-stuttgart.de (darus.uni-stuttgart.de)|129.69.7.87|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://s3.tik.uni-stuttgart.de/fokus-dv-prod-1/10.18419/darus-2986/181657747c0-9ae7acea320f?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27ns_incom_inhom_2d_512-136.h5&response-content-type=application%2Fx-h5&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20250819T075158Z&X-Amz-SignedHeaders=host&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20250819%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Expires=172800&X-Amz-Signature=7627af833cc652a49d6f0cac170adfe0d2588c7f174c1e2226bec5e4d17cf82f [following]
# ...

# %%
dirname = "./dataset_01"
data = [h5py.File(dirname, "r")] # [<HDF5 file "dataset_01" (mode r)>]

# print(len(data)) # 1
file = data[0]
# print(list(file.keys())) # ['force', 'particles', 't', 'velocity']
dataset = file['velocity'] # <class 'h5py._hl.dataset.Dataset'>
# Out:
# <class 'h5py._hl.dataset.Dataset'>

# %%
t1 = dataset[:] # (4, 1000, 512, 512, 2)

# %%
t2 = t1[0,0,:,:,0]
import matplotlib.pyplot as plt
plt.imshow(t2)
