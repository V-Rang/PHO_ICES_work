# %%
# generate data for the RL-ROM example:

import pickle
import numpy as np
import torch

with open("../CAE_transf/tacc_vals.pkl", 'rb') as f:
    tacc_vals = pickle.load(f)

with open("era5_example_1_data.pkl", 'rb') as file:
    loaded_data = pickle.load(file)

data_var = loaded_data['u10m_values']
lat_vals = loaded_data['lat_vals']
long_vals = loaded_data['long_vals']

train_split = int(0.8*data_var.shape[0])
S_train_org = data_var[:train_split]
S_test_org = data_var[train_split:]

S_train = S_train_org.reshape(S_train_org.shape[0], S_train_org.shape[1] * S_train_org.shape[2]).T
S_test = S_test_org.reshape(S_test_org.shape[0], S_test_org.shape[1] * S_test_org.shape[2]).T

X_train = S_train[:,:-1]
Y_train = S_train[:,1:]

# print(X_train.shape, Y_train.shape)

torch_device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

X_train = torch.tensor(X_train, dtype = torch.float32, device = torch_device)
Y_train = torch.tensor(Y_train, dtype = torch.float32, device = torch_device)

U_vals, sing_vals, Vt_vals = torch.linalg.svd(X_train, full_matrices = False)
# Out:
# /workspace/venu_files/ml-env/lib/python3.10/site-packages/torch/cuda/__init__.py:716: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
with open("../data/u_10m_comp_vals_2.pkl", 'rb') as f:
    loaded_data = pickle.load(f)

S_train = loaded_data['train']['data']
train_times = loaded_data['train']['time']

S_test = loaded_data['test']['data']
test_times = loaded_data['test']['time']

S_val = loaded_data['val']['data']
val_times = loaded_data['val']['time']

lat_vals = loaded_data['lat_vals']
lon_vals = loaded_data['lon_vals']

r_val = loaded_data['r95']
Nh_val = S_train.shape[0]
r_val = 20

# print(S_train.shape, S_test.shape) # (22701, 985) (22701, 124)

X_train = S_train[:,:-1]
Y_train = S_train[:,1:]

torch_device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

X_train = torch.tensor(X_train, dtype = torch.float32, device = torch_device)
Y_train = torch.tensor(Y_train, dtype = torch.float32, device = torch_device)

U_vals, sing_vals, Vt_vals = torch.linalg.svd(X_train, full_matrices = False)
# Out:
# (22701, 985) (22701, 124)

# %%
# print(S_train.shape)
# print(S_test.shape)

X_train = S_train[:,:-1]
Y_train = S_train[:,1:]

torch_device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

X_train = torch.tensor(X_train, dtype = torch.float32, device = torch_device)
Y_train = torch.tensor(Y_train, dtype = torch.float32, device = torch_device)

U_vals, sing_vals, Vt_vals = torch.linalg.svd(X_train, full_matrices = False)

# %%
# U_vals = loaded_data['U_vals']
# sing_vals = loaded_data['sing_vals']
# Vt_vals = loaded_data['Vt_vals']

# print(S_train.shape, U_vals.shape, sing_vals.shape, Vt_vals.shape)
# Out:
# (22701, 985) (22701, 985) (985,) (985, 985)
